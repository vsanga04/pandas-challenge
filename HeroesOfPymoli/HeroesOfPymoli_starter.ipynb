# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
Player_Counts = len(purchase_data["SN"].value_counts())

print(f"Total Players: {(Player_Counts)}")
# Out:
# Total Players: 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
Item_Counts = purchase_data["Item ID"].value_counts()
Unique_item_counts = len(Item_Counts)
Avg_price = purchase_data["Price"].mean()
Num_purhases = purchase_data['Purchase ID'].count()
Total_Rev= purchase_data['Price'].sum()

# print(f"Total items: {len(Item_Counts)}")
# print(f"Avg Price: {Avg_price}")
# print(f'Number of Purchases: {Num_purhases}')
# print(f'Total Rev: {Total_Rev}')

Summary_Totals= pd.DataFrame({"Number of Unique Items": Unique_item_counts,
                             "Average Price": Avg_price,
                              "Number of Purchases":Num_purhases, 
                              "Total Revenue": [Total_Rev]})
Summary_Totals.style.format({"Average Price":"${:,.2f}", "Total Revenue" : "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_58aec1c0_9c2a_11eb_8d09_a3945d4102bb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58aec1c0_9c2a_11eb_8d09_a3945d4102bblevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_58aec1c0_9c2a_11eb_8d09_a3945d4102bbrow0_col0" class="data row0 col0" >179</td>
#                         <td id="T_58aec1c0_9c2a_11eb_8d09_a3945d4102bbrow0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_58aec1c0_9c2a_11eb_8d09_a3945d4102bbrow0_col2" class="data row0 col2" >780</td>
# ...

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
Group_Gender = purchase_data.groupby("Gender") 
Count_Gender = Group_Gender.nunique()["SN"]
Count_Gender.head()

Gender_Percentages = Count_Gender/Player_Counts*100

Gender_Summary = pd.DataFrame({"Gender Percentages":Gender_Percentages,"Gender Count": Count_Gender})

Gender_Summary.style.format({"Gender Percentages":"{:.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_58b37850_9c2a_11eb_a668_a3945d4102bb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Gender Percentages</th>        <th class="col_heading level0 col1" >Gender Count</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58b37850_9c2a_11eb_a668_a3945d4102bblevel0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_58b37850_9c2a_11eb_a668_a3945d4102bbrow0_col0" class="data row0 col0" >14.06%</td>
#                         <td id="T_58b37850_9c2a_11eb_a668_a3945d4102bbrow0_col1" class="data row0 col1" >81</td>
#             </tr>
#             <tr>
#                         <th id="T_58b37850_9c2a_11eb_a668_a3945d4102bblevel0_row1" class="row_heading level0 row1" >Male</th>
# ...

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
Purch_Count = Group_Gender.nunique()["Purchase ID"]
Purch_Count.head()

Avg_price_by_gender = Group_Gender["Price"].mean()
Avg_price_by_gender.head()

Purchase_total_by_gender = Group_Gender["Price"].sum()
Purchase_total_by_gender.head()

Avg_purchase_total_by_gender = Purchase_total_by_gender/Count_Gender
Avg_purchase_total_by_gender.head()

Purchase_summary_gender = pd.DataFrame({"Purchase Count": Purch_Count, 
                                        "Average Purchase Price": Avg_price_by_gender, 
                                       "Total Purchase Value": Purchase_total_by_gender,
                                       "Avg Purchase Total Per Person": Avg_purchase_total_by_gender})
Purchase_summary_gender.style.format({"Average Purchase Price":"${:,.2f}",
                                     "Total Purchase Value": "${:,.2f}",
                                     "Avg Purchase Total Per Person": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_58b82c48_9c2a_11eb_9a36_a3945d4102bb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Purchase Total Per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58b82c48_9c2a_11eb_9a36_a3945d4102bblevel0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_58b82c48_9c2a_11eb_9a36_a3945d4102bbrow0_col0" class="data row0 col0" >113</td>
# ...

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# print(purchase_data["Age"].max())
# print(purchase_data["Age"].min())

bins = [0,9,14,19,24,29,34,39,45]
group_labels = ["<10", "10-14", "15-19","20-24","25-29","30-34","35-39","40+"]

purchase_data["Age Group"] = pd.cut(purchase_data["Age"],bins,labels=group_labels)
purchase_data.head()

Age = purchase_data.groupby("Age Group")
Purch_Count_age = Age["Purchase ID"].count()
Purch_Count_age.head()

Count_age = Age["SN"].nunique()
Count_age.head()


Player_Percentage = Count_age/Player_Counts*100
Player_Percentage.head()

Age_Demographics = pd.DataFrame({"Total Count": Count_age,
                                "Percentage of Players": Player_Percentage})
Age_Demographics.style.format({"Percentage of Players": "{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_58bcc128_9c2a_11eb_9408_a3945d4102bb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58bcc128_9c2a_11eb_9408_a3945d4102bblevel0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_58bcc128_9c2a_11eb_9408_a3945d4102bbrow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_58bcc128_9c2a_11eb_9408_a3945d4102bbrow0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_58bcc128_9c2a_11eb_9408_a3945d4102bblevel0_row1" class="row_heading level0 row1" >10-14</th>
# ...

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
Avg_price_age = Age["Price"].mean()
Avg_price_age.head()

Total_purchase_age = Age["Price"].sum()
Total_purchase_age.head()

Avg_Total_purchase_age = Total_purchase_age/Count_age
Avg_Total_purchase_age.head()


Age_Purchase_Analysis = pd.DataFrame({"Purchase Count": Purch_Count_age,
                                "Avg Purchase Price by Age": Avg_price_age,
                                "Total Purch Value by Age": Total_purchase_age,
                                "Avg Total Purchase per person": Avg_Total_purchase_age})

Age_Purchase_Analysis.style.format({"Avg Purchase Price by Age": "${:,.2f}",
                               "Total Purch Value by Age": "${:,.2f}",
                               "Avg Total Purchase per person": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_58c6f27a_9c2a_11eb_8afd_a3945d4102bb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Avg Purchase Price by Age</th>        <th class="col_heading level0 col2" >Total Purch Value by Age</th>        <th class="col_heading level0 col3" >Avg Total Purchase per person</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58c6f27a_9c2a_11eb_8afd_a3945d4102bblevel0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_58c6f27a_9c2a_11eb_8afd_a3945d4102bbrow0_col0" class="data row0 col0" >23</td>
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
Top_spenders = purchase_data.groupby("SN")

Purch_Count_SN = Top_spenders["Purchase ID"].count()
Purch_Count_SN.head()

Avg_Purch_Price_Top_Spenders = Top_spenders["Price"].mean()
Avg_Purch_Price_Top_Spenders.head()

Total_purchase_topspenders = Top_spenders["Price"].sum()
Total_purchase_topspenders.head()

Top_Spenders_summary = pd.DataFrame({"Purcahse Count": Purch_Count_SN,
                                    "Avg Purch Price": Avg_Purch_Price_Top_Spenders,
                                    "Total Purchase Value": Total_purchase_topspenders})


Top_Spenders_summary.head()

Top_Spenders_summary = Top_Spenders_summary.sort_values(['Total Purchase Value'], ascending=False).groupby('SN').head(4)

Top_Spenders_summary.style.format({"Avg Purch Price": "${:,.2f}",
                                  "Total Purchase Value": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_58cb0db0_9c2a_11eb_9b23_a3945d4102bb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purcahse Count</th>        <th class="col_heading level0 col1" >Avg Purch Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58cb0db0_9c2a_11eb_9b23_a3945d4102bblevel0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_58cb0db0_9c2a_11eb_9b23_a3945d4102bbrow0_col0" class="data row0 col0" >5</td>
#                         <td id="T_58cb0db0_9c2a_11eb_9b23_a3945d4102bbrow0_col1" class="data row0 col1" >$3.79</td>
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
Items = purchase_data.groupby(["Item ID", "Item Name"])

Purch_Count_Items = Items["Purchase ID"].count()
Purch_Count_Items.head()

Item_price = Items["Price"].mean()
Item_price.head()

Total_Item_purch = Items["Price"].sum()
Total_Item_purch.head()


Popular_Items = pd.DataFrame({"Purchase Count": Purch_Count_Items,
                            "Item Price": Item_price,
                            "Total Purchase Value": Total_Item_purch})

Popular_Items.head()
# Out:
#                             Purchase Count  Item Price  Total Purchase Value
# Item ID Item Name
# 0       Splinter                         4      1.2800                  5.12
# 1       Crucifer                         4      2.9425                 11.77
# 2       Verdict                          6      2.4800                 14.88
# 3       Phantomlight                     6      2.4900                 14.94
# 4       Bloodlord's Fetish               5      1.7000                  8.50

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
Popular_Items = Popular_Items.sort_values(['Total Purchase Value'], ascending=False).groupby('Item ID').head(4)
Popular_Items.head()
Popular_Items.style.format({"Item Price": "${:,.2f}",
                                  "Total Purchase Value": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_58dcfd4c_9c2a_11eb_af48_a3945d4102bb" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58dcfd4c_9c2a_11eb_af48_a3945d4102bblevel0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_58dcfd4c_9c2a_11eb_af48_a3945d4102bblevel1_row0" class="row_heading level1 row0" >Final Critic</th>
# ...
